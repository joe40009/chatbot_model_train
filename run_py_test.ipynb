# %%
# !python RASA_train.py --config='./train.yaml'
# Out:
# /usr/local/lib/python3.6/dist-packages/rasa_nlu/__init__.py:12: UserWarning: The 'rasa_nlu' package has been renamed. You should change your imports to use 'rasa.nlu' instead.
#   UserWarning,
# RASA_train.py:17: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(stream)
# ----------head 5 data----------
# ('合約查詢', '我現在的資費方案是?', '方案,資費', 'PROJ,PROJ')
# ('合約查詢', '我的方案是啥', '方案', 'PROJ')
# ('合約查詢', '請告訴我當初辦理的專案', '專案', 'PROJ')
# ('合約查詢', '目前資費是什麼', '資費', 'PROJ')
# ('合約查詢', '我忘了當初申辦的資費了', '資費,申辦', 'PROJ,BID')
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
# !python LSTM_train.py --config='./LSTM_train.yaml'
# Out:
# Using TensorFlow backend.
# LSTM_train.py:28: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(stream)
# ----------head 5 data----------
# ('我現在的資費方案是?', '合約查詢')
# ('我的方案是啥', '合約查詢')
# ('請告訴我當初辦理的專案', '合約查詢')
# ('目前資費是什麼', '合約查詢')
# ('我忘了當初申辦的資費了', '合約查詢')
# ----------NER count----------
# {'合約查詢': 477, '帳務查詢': 126, '魔速方塊1.0': 18, '魔速方塊2.0': 30}
# ----------class2eng----------
# {'合約查詢': 0, '帳務查詢': 1, '魔速方塊1.0': 2, '魔速方塊2.0': 3}
# ----------head 5 train data----------
# 我現在的資費方案是?
# 我的方案是啥
# 請告訴我當初辦理的專案
# 目前資費是什麼
# 我忘了當初申辦的資費了
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.925 seconds.
# Prefix dict has been built successfully.
# ----------start w2v train----------
# ----------w2v train complete----------
# ----------generate_id2wec----------
# ...
